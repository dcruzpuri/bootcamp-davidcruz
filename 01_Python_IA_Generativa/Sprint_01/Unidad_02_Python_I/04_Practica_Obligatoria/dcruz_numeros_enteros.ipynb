# %%
# 1. Solicitar 3 números separados por comas
entrada = input("Introduce 3 números enteros separados por comas (ejemplo: 1,2,3): ")

# 2. Convertir la entrada en lista de enteros
numeros = [int(x) for x in entrada.split(",")]

# 3. Calcular máximo, mínimo y suma
maximo = max(numeros)
minimo = min(numeros)
suma = sum(numeros)

# 4. Comprobar la afirmación
afirmacion = (maximo - minimo) == (suma / 5)

# 5. Mostrar resultados
print(f"Lista de números: {numeros}")
print(f"Número máximo: {maximo}")
print(f"Número mínimo: {minimo}")
print(f"Suma total: {suma}")
print(f"¿El máximo menos el mínimo es igual a la suma dividida por 5? {afirmacion}")
# Out:
# Lista de números: [3, 4, 69]
# Número máximo: 69
# Número mínimo: 3
# Suma total: 76
# ¿El máximo menos el mínimo es igual a la suma dividida por 5? False
